# %%
import pandas as pd

# %%
import os
os.listdir()
# Out:
# ['runner.ipynb', 'test.csv', 'train.csv']

# %%
pd.read_csv('test.csv').to_parquet('test.parquet')
pd.read_csv('train.csv').to_parquet('train.parquet')
