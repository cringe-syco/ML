# %% [markdown]
# Introduction to statistical learning

# %% [markdown]
# Linear Regression

# %% [raw]
# Linear Model
#     Y = mX + C
#     C is a irreducible error. mX can be controlled to be fitting
#     Y = c0 + c1X1 +c2X2 + c3X3 .....
#     We get the constants c from different methods
#     A widely used approach is Least Square Methods
#     It minimizes the sum of squared errors.

# %% [raw]
# Two types:
#     Parametric and Non-Parametric
#     Parametric: Assumes a specific form for the function. considered underfitting.
#     Non-Parametric: Does not assume a specific form. a level of smoothness is assumed.
#     Non-parametric methods can be more flexible and adapt to the data better,
#     but they may require more data to achieve good performance.
#     Non-parametric with low smoothness may lead to overfitting.
#     not very good for new data prediction.
#
# when inference is the goal, restricted parametric models are often preferred.
# when prediction is the goal, non-parametric models are often preferred.
#
# Parametric approaches help in feature selection, model choice, data collection, preprocessing, transformation, and normalization decisions.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)                              ![image.png](attachment:image.png)
# non parametric
#
#
#
# parametric

# %% [raw]
# Supervised Learning
#     Supervised learning is a type of machine learning where the model is trained on labeled data.
#     The model learns to map inputs to outputs based on the provided labels.
#     It can be used for both regression and classification tasks.
#
#     In supervised learning, the model is trained using a dataset that contains input-output pairs.
#     The goal is to learn a function that can predict the output for new, unseen inputs.
#
#     Common algorithms include linear regression, logistic regression, decision trees, random forests, support vector machines (SVM), and neural networks.
# Unsupervised Learning
#     Unsupervised learning is a type of machine learning where the model is trained on unlabeled data.
#     The model learns to find patterns and relationships in the data without explicit labels.
#
#     It can be used for clustering, dimensionality reduction, and anomaly detection tasks.
#
#     Common algorithms include k-means clustering, hierarchical clustering, principal component analysis (PCA), and t-distributed stochastic neighbor embedding (t-SNE).
#
#     Unsupervised learning is often used for exploratory data analysis and feature extraction.

# %% [raw]
# A problem can be quantitative or qualitative.
# Quantitative problems involve numerical data and can be solved using mathematical models, statistical methods,
#     or machine learning algorithms. Examples include predicting sales, stock prices, or customer behavior.
# Qualitative problems involve categorical data and often require domain knowledge, expert judgment, or qualitative analysis.
#     Examples include predicting the class of an object, sentiment analysis, or text classification.
#
# Regression
# linear regression and polynomial regression are two common types of regression analysis. qualitative..
# logistic regression is a classification algorithm that predicts the probability of a binary outcome. 0 and 1. also considered as regression.
#
# Classification
#     k-nearest neighbors (KNN) is a simple classification algorithm that assigns a class to a data point based on the classes of its k nearest neighbors.
#     Decision trees are a type of classification algorithm that uses a tree-like structure to make decisions based on feature values.
#     boosting, Random Forest, and Support Vector Machines (SVM) are other popular classification algorithms.

# %% [raw]
# Measuring the quality of fit:
#     The quality of fit of a model can be measured using various metrics, such as:
#     - Mean Absolute Error (MAE): The average absolute difference between predicted and actual values.
#     - Mean Squared Error (MSE): The average squared difference between predicted and actual values.
#     - Root Mean Squared Error (RMSE): The square root of the MSE, providing a measure in the same units as the target variable.
#     - R-squared: The proportion of variance in the target variable that is explained by the model.
#     - Adjusted R-squared: A modified version of R-squared that accounts for the number of predictors in the model.
